# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('/data/src/xflsvg/src')

# %%
from xflsvg import *
import os

path = '/data/samples/MLP509_091'
# path = '/data/samples/422/MLP422_100'
xfl = XflReader(path)
timeline = xfl.get_timeline()

output_path = '/data/samples/out'
# !rm -r $output_path
os.makedirs('/data/samples/out', exist_ok=True)

for i, frame in enumerate(timeline):
    with SvgRenderer() as renderer:
        frame.render()
    svg = renderer.compile(xfl.width, xfl.height)
    with open(f'{output_path}/frame%03d.svg' % i, 'w') as outfile:
        svg.write(outfile, encoding='unicode')
# Out:
# file:///MLP509_091.xfl/Scene 1
# GUIDE/new_field_guide
# GUIDE/CAMERA GUIDE
# scene
# ~MTDA*Character
# MTDA*Rotation_Notes
# patch03
# MTDA*Mane_toupee
# ~MTDA*Head
# MTDA*Ear
# MTDA*Earring
# MTDA*Hair_Toupee
# MTDA*Brow
# MTDA*Blink3-4
# MTDA*Mouth_back3-4
# MTDA*Nostril
# MTDA*Chin
# MTDA*Nose
# MTDA*Tongue
# MTDA*Teeth
# MTDA*Mouth_side
# MTDA*Mouth_front
# MTDA*Whisker
# MTDA*InsideMouth
# MTDA*MouthCircle(front)
# MTDA*Mouth_3-4
# MTDA*Eyewhite
# MTDA*Eye_highlight
# MTDA*Eye_pupil
# MTDA*Eye_iris
# MTDA*Skull
# MTDA*Neck
# MTDA*Brooch
# MTDA*Collar
# MTDA*Torso
# MTDA*FrontLeg_back3-4
# MTDA*Hoofline
# MTDA*Kneecap
# MTDA*FrontLeg_mid
# MTDA*FrontLeg_top
# MTDA*FrontLeg_bottom
# MTDA*Hoof
# MTDA*FrontLeg_front
# MTDA*FrontLeg_3-4
# MTDA*FrontLeg_side
# MTDA*HindLeg_back3-4
# MTDA*Knee(Top)
# MTDA*HindLeg_bottom
# MTDA*HindLeg_top
# MTDA*Knee(Bottom)
# MTDA*HindLeg_side
# MTDA*Tail
# MTDA*Tailtuft
# MTDA*Tail_main
# MTDA*HindLeg_3-4
# MTDA*Bum
# MTDA*HindLeg_front
# MTDA*HindLeg_back3-4_far
# MTDA*Shadow
# ~IUC01*Character
# IUC01*Rotation_Notes
# -NT-ThisFrameNotFinal
# IUC01*FrontLeg_3-4
# IUC01*FrontLeg_3-4_hoof
# IUC01*FrontLeg_3-4_lower
# IUC01*HoofWrinkle
# IUC01*FrontLeg_3-4_upper
# buttpatch
# shoulder
# IUC01*Tail
# IUC01*Tail_5
# IUC01*Tail_4
# IUC01*Tail_3
# IUC01*Tail_2
# IUC01*Tail_1
# IUC01*Mane
# IUC01*HindLeg_back
# IUC01*KneePatch
# IUC01*HindLeg_3-4rear_lower
# IUC01*HindLeg_3-4_top
# IUC01*HindLeg_3-4rear
# IUC01*CutieMark
# IUC01*Torso
# IUC01*FrontLeg_3-4rear
# IUC01*Neck
# ~IUC01*Head
# IUC01*Ear
# IUC01*Horn
# SVFGSERGDSRF
# IUC01*Hair_06
# IUC01*Hair_01
# fgsadf bdsfadf
# dfbgzdgzd
# jtrzetrt
# RD*Hair_01xxx
# RD*HairBit1xxx
# RD*HairBit4xxx
# RD*HairBit3xxx
# RD*HairBit2xxx
# DXFGHXDFGDXFG
# Tween 1
# HZDFT
# Tween 3
# XTJXFGXF
# Tween 5
# XFXFGJ
# Tween 7
# IUC01*Cheek
# IUC01*FX_blush
# IUC01*Nostrilsync_3-4
# IUC01*Nostril_3-4
# IUC01*Nostrilsync_offcenter
# IUC01*Nostril(comp)_front
# IUC01*Nostril_front
# IUC01*Nostrilsync_front
# IUC01*Nostrilsync_side
# IUC01*MouthPatch
# IUC01*Tongue
# IUC01*Teeth
# IUC01*MouthInterior
# IUC01*Nose
# IUC01*Nostrilsync_3-4back
# IUC01*Nostril_3-4rear
# IUC01*Mouth_3-4
# IUC01*NoseWrinkle
# IUC01*Mouth_front(hole)
# IUC01*Wrinkle
# IUC01*Mouth_side
# IUC01*Mouth_3-4back
# IUC01*NostrilCircle
# IUC01*WrinkleNose(comp)
# IUC01*Mouth_front(chin)
# IUC01*Brow_3-4rear
# IUC01*Lashes_02
# IUC01*Lash
# IUC01*Brow_front
# IUC01*Brow_3-4
# IUC01*Blink_3-4
# IUC01*Blink_front
# IUC01*Blink_3-4rear
# IUC01*Blink_3-4far
# IUC01*Eyewhite_3-4
# IUC01*Eyewhite_front
# IUC01*Eyewhite_3-4rear
# IUC01*Hilights
# IUC01*Pupil
# IUC01*Iris
# IUC01*Eyewhite_3-4far
# IUC01*Hair_07
# IUC01*Hair_02
# IUC01*Skull
# IUC01*Torso(overlap)
# IUC01*Chest
# IUC01*HindLeg_5-8
# IUC01*HindLeg_side
# IUC01*HindLeg_3-4
# IUC01*FrontLeg_front
# IUC01*HindLeg_7-8
# IUC01*HindLeg_front
# IP*Shadow
# Designs/mlp509_087_ext_ponyville_bowling_alley_day_colour
# ref/jnnj
# ref/vh
# ref/-m,;
# ref/cg
# ref/k;
# ref/kmkjk
# ref/vbjmvb
# rm: cannot remove '/data/samples/out': No such file or directory

# %%
import numpy
start = numpy.matrix([[0.7044677734375, 0], [0, 0.105255126953125]])
end = numpy.matrix([[2.43000793457031, 1.40292358398438], [1.130126953125, 1.13653564453125]])

# %%
import numpy
import math

def polar_decomposition(matrix):
    u, s, vh = numpy.linalg.svd(matrix)
    pu = u @ vh # rotation matrix
    angle = math.atan2(pu[1,0], pu[0,0])
    
    pp = vh.T @ numpy.diag(s) @ vh # scaling matrix
#     scale = numpy.diag(pp)
#     skew = pp / scale
    return pp, angle # scale, angle, skew

def recompose_polar(scale, angle, skew):
    pp = numpy.multiply(skew, scale)
    pu = numpy.array([[math.cos(angle), -math.sin(angle)], [math.sin(angle), math.cos(angle)]])
    return pu @ pp

# scale, angle, skew = polar_decomposition(end)
# recon = recompose_polar(scale, angle, skew)
# print(recon)
# print(end)

# %%
# Out:
# (2,)
# (2, 2)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [240], in <module>
#       1 scale, angle, skew = polar_decomposition(end)
# ----> 3 recon = recompose_polar(scale, angle, skew)
#       5 print(recon)
#       6 print(end)
#
# Input In [239], in recompose_polar(scale, angle, skew)
#      15 print(scale.shape)
#      16 print(skew.shape)
# ---> 17 pp = skew * scale
#      18 pu = numpy.array([[math.cos(angle), -math.sin(angle)], [math.sin(angle), math.cos(angle)]])
#      19 return pu @ pp
#
# File /usr/local/lib/python3.8/dist-packages/numpy/matrixlib/defmatrix.py:218, in matrix.__mul__(self, other)
#     215 def __mul__(self, other):
#     216     if isinstance(other, (N.ndarray, list, tuple)) :
#     217         # This promotes 1-D vectors to row vectors
# --> 218         return N.dot(self, asmatrix(other))
#     219     if isscalar(other) or not hasattr(other, '__rmul__') :
#     220         return N.dot(self, other)
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# ValueError: shapes (2,2) and (1,2) not aligned: 2 (dim 1) != 1 (dim 0)

# %%
start_props = polar_decomposition(start)
end_props = polar_decomposition(end)

steps = 20

diff_det = -(start_props[0] - end_props[0]) / (steps - 1)
diff_angle = 0 # -(start_props[1] - end_props[1]) / (steps-1)
diff_skew = 0 # -(start_props[2] - end_props[2]) / (steps-1)

print(diff_det, diff_angle, diff_skew)

current_det, current_angle, current_skew = start_props[:]

for i in range(steps-1):
    new_det = start_props[0] + i * diff_det
    new_angle = start_props[1] + i * diff_angle
    new_skew = start_props[2] + i * diff_skew
    print(recompose_polar(new_det, new_angle, new_skew))
# Out:
# [-0.01754409  0.01620308] 0 0
# [[0.70446777 0.        ]
#  [0.         0.10525513]]
# [[0.68692368 0.        ]
#  [0.         0.1214582 ]]
# [[0.66937959 0.        ]
#  [0.         0.13766128]]
# [[0.6518355  0.        ]
#  [0.         0.15386435]]
# [[0.63429141 0.        ]
#  [0.         0.17006743]]
# [[0.61674732 0.        ]
#  [0.         0.18627051]]
# [[0.59920323 0.        ]
#  [0.         0.20247358]]
# [[0.58165914 0.        ]
#  [0.         0.21867666]]
# [[0.56411505 0.        ]
#  [0.         0.23487973]]
# [[0.54657096 0.        ]
#  [0.         0.25108281]]
# [[0.52902687 0.        ]
#  [0.         0.26728588]]
# [[0.51148278 0.        ]
#  [0.         0.28348896]]
# [[0.49393869 0.        ]
#  [0.         0.29969203]]
# [[0.4763946  0.        ]
#  [0.         0.31589511]]
# [[0.45885051 0.        ]
#  [0.         0.33209819]]
# [[0.44130642 0.        ]
#  [0.         0.34830126]]
# [[0.42376233 0.        ]
#  [0.         0.36450434]]
# [[0.40621824 0.        ]
#  [0.         0.38070741]]
# [[0.38867415 0.        ]
#  [0.         0.39691049]]

# %%
from bs4 import BeautifulSoup
from glob import glob
from matplotlib import pyplot as plt

def read_matrices(path):
    for f in sorted(glob(path)):
        with open(f) as inp:
            soup = BeautifulSoup(inp.read(), 'html5lib')
            for g in soup.svg.findChildren('g', recursive=False):
                if g.has_attr('id'):
                    continue
                if g['transform']:
                    data = g['transform']
                    left = data.find('(') + 1
                    right = data.find(')')
                    elements = [float(x.strip()) for x in data[left:right].split(',')]
                    yield numpy.array(elements[:4]).reshape((2,2))
                    break

mats = list(read_matrices('/data/samples/tweens-both/*'))

def scales(m):
#     return numpy.linalg.svd(m)[1]
    scale, angle, skew = polar_decomposition(m)
    u, s, vt = numpy.linalg.svd(skew)
    return s
#     vals, vects = numpy.linalg.eig(m)
#     return vals
    

def decompose(m):
    mat = numpy.linalg.svd(m)
    angle = math.atan2(mat[0][1,0], mat[0][0,0])
    scale = mat[1]
    skew = mat[2]
#     return mat
#     return math.atan2(mat[1,0], mat[0,0]) % math.pi
#     pp, angle = polar_decomposition(m)
#     u, d, vt = numpy.linalg.svd(pp)
    
    return angle, scale, skew



plt.figure()
for i in range(len(mats) - 1):
    cur = decompose(mats[i])
    post = decompose(mats[i+1])
    
    d_angle = (post[0] - cur[0]) % math.pi - math.pi/2
    d_skew = (post[2] - cur[2]) % (math.pi / 2)
    d_scale = post[1] - cur[1]
    plt.plot(i, d_angle, 'k.')

plt.show()
plt.close()


# plt.figure()
# for i in range(len(mats) - 1):
#     cur = decompose(mats[i])
#     post = decompose(mats[i+1])
    
#     d_angle = (post[0] - cur[0]) % math.pi - math.pi
#     d_skew = (post[2] - cur[2]) % (math.pi / 2)
#     d_scale = post[1] - cur[1]
#     plt.plot(i, post[1][0] / cur[1][0], 'k.')

# plt.show()
# plt.close()


    
# d = [scales(x) for x in mats]
# for z in [x - y for x,y in zip(d[1:], d[:-1])]:
#     print(z)

# print('expected:', (scales(end) - scales(start)) / (len(d)))
# it overshoots by 2 on x, 3 on y until the last one, which corrects the overshoot?
# print(numpy.linalg.inv(mats[0]) @ mats[-1])
# print(numpy.linalg.inv(start) @ end)
