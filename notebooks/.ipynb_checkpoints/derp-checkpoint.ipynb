# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('/data/src/xflsvg/src')

# %%
from xflsvg import *
from xflsvg.svgrenderer import *
import os

path = '/data/samples/MLP509_091'
# path = '/data/samples/422/MLP422_100'
xfl = XflReader(path)
timeline = xfl.get_safe_asset('~IUC01&#042Character')
# timeline = xfl.get_timeline()

output_path = '/data/samples/out'
# !rm -r $output_path
os.makedirs('/data/samples/out', exist_ok=True)

for i, frame in enumerate(timeline):
    with SvgRenderer() as renderer:
        frame.render()
    svg = renderer.compile(xfl.width, xfl.height, x=-xfl.width/2, y=-xfl.height/2)
    with open(f'{output_path}/frame%03d.svg' % i, 'w') as outfile:
        svg.write(outfile, encoding='unicode')

# %%
from xflsvg import *
from xflsvg.exporter import *
import os

path = '/data/samples/MLP509_091'
# path = '/data/samples/422/MLP422_100'
xfl = XflReader(path)
timeline = xfl.get_safe_asset('~IUC01&#042Character')
# timeline = xfl.get_timeline()

exporter = XflExporter()
for i, frame in enumerate(timeline):
    with exporter:
        frame.render()
    exporter.save_frame()
    
shapes, frames, timeline = exporter.compile_frames()
print(timeline)

print('done')
# Out:
# loading ~IUC01*Character
# loading IUC01*Rotation_Notes
# loading -NT-ThisFrameNotFinal
# loading IUC01*FrontLeg_3-4
# loading IUC01*FrontLeg_3-4_hoof
# loading IUC01*FrontLeg_3-4_lower
# loading IUC01*HoofWrinkle
# loading IUC01*FrontLeg_3-4_upper
# loading buttpatch
# loading shoulder
# loading IUC01*Tail
# loading IUC01*Tail_5
# loading IUC01*Tail_4
# loading IUC01*Tail_3
# loading IUC01*Tail_2
# loading IUC01*Tail_1
# loading IUC01*Mane
# loading IUC01*HindLeg_back
# loading IUC01*KneePatch
# loading IUC01*HindLeg_3-4rear_lower
# loading IUC01*HindLeg_3-4_top
# loading IUC01*HindLeg_3-4rear
# loading IUC01*CutieMark
# loading IUC01*Torso
# loading IUC01*FrontLeg_3-4rear
# loading IUC01*Neck
# loading ~IUC01*Head
# loading IUC01*Ear
# loading IUC01*Horn
# loading SVFGSERGDSRF
# loading IUC01*Hair_06
# loading IUC01*Hair_01
# loading fgsadf bdsfadf
# loading dfbgzdgzd
# loading jtrzetrt
# loading RD*Hair_01xxx
# loading RD*HairBit1xxx
# loading RD*HairBit4xxx
# loading RD*HairBit3xxx
# loading RD*HairBit2xxx
# loading DXFGHXDFGDXFG
# loading Tween 1
# loading HZDFT
# loading Tween 3
# loading XTJXFGXF
# loading Tween 5
# loading XFXFGJ
# loading Tween 7
# loading IUC01*Cheek
# loading IUC01*FX_blush
# loading IUC01*Nostrilsync_3-4
# loading IUC01*Nostril_3-4
# loading IUC01*Nostrilsync_offcenter
# loading IUC01*Nostril(comp)_front
# loading IUC01*Nostril_front
# loading IUC01*Nostrilsync_front
# loading IUC01*Nostrilsync_side
# loading IUC01*MouthPatch
# loading IUC01*Tongue
# loading IUC01*Teeth
# loading IUC01*MouthInterior
# loading IUC01*Nose
# loading IUC01*Nostrilsync_3-4back
# loading IUC01*Nostril_3-4rear
# loading IUC01*Mouth_3-4
# loading IUC01*NoseWrinkle
# loading IUC01*Mouth_front(hole)
# loading IUC01*Wrinkle
# loading IUC01*Mouth_side
# loading IUC01*Mouth_3-4back
# loading IUC01*NostrilCircle
# loading IUC01*WrinkleNose(comp)
# loading IUC01*Mouth_front(chin)
# loading IUC01*Brow_3-4rear
# loading IUC01*Lashes_02
# loading IUC01*Lash
# loading IUC01*Brow_front
# loading IUC01*Brow_3-4
# loading IUC01*Blink_3-4
# loading IUC01*Blink_front
# loading IUC01*Blink_3-4rear
# loading IUC01*Blink_3-4far
# loading IUC01*Eyewhite_3-4
# loading IUC01*Eyewhite_front
# loading IUC01*Eyewhite_3-4rear
# loading IUC01*Hilights
# loading IUC01*Pupil
# loading IUC01*Iris
# loading IUC01*Eyewhite_3-4far
# loading IUC01*Hair_07
# loading IUC01*Hair_02
# loading IUC01*Skull
# loading IUC01*Torso(overlap)
# loading IUC01*Chest
# loading IUC01*HindLeg_5-8
# loading IUC01*HindLeg_side
# loading IUC01*HindLeg_3-4
# loading IUC01*FrontLeg_front
# loading IUC01*HindLeg_7-8
# loading IUC01*HindLeg_front
# loading IP*Shadow
# [2183, 2683, 2868, 3053, 3238, 3454, 3670, 3887, 4069, 4271, 4479, 4692, 4873, 5054, 5235, 5437, 5618, 5820, 6001, 6203, 6384, 6586, 6767, 6969, 7150, 7331, 7512, 7693, 7874, 8055, 8236, 8417, 8598, 8815, 8996, 9177, 9358, 9539, 9720, 9937, 10143, 10360, 10541, 10723, 10905, 11086, 11267, 11448, 11629, 11832, 12014, 12196, 12378, 12559, 12740, 12922, 13104, 13286, 13468, 13650, 13832, 14014, 14196, 14390, 14589, 14771, 14953, 15135, 15317, 15510, 15690, 15881, 16065, 16266, 16446, 16648, 16828, 17008, 17188, 17395, 17575, 17755, 17935, 18115, 18295, 18475, 18655, 18835, 19015, 19195, 19375, 19555, 19735, 19915, 20095, 20275, 20455, 20635, 20815, 20995, 21175, 21355, 21535, 21715, 21895, 22075, 22255, 22450, 22632, 22814, 22996, 23178, 23360, 23543, 23726, 23909, 24092, 24275, 24458, 24641, 24824, 25007, 25190, 25373, 25553, 25733, 26007, 26206, 26423, 26697, 26914, 27114, 27302, 27490, 27678, 27866, 28054, 28242, 28430, 28618, 28806, 28985, 29164, 29343, 29522, 29701, 29880, 30059, 30238, 30417, 30596, 30775, 30954, 31133, 31312, 31491, 31670, 31849, 32028, 32207, 32386, 32565, 32743, 32931, 33110, 33289, 33468, 33647, 33826, 34005, 34184, 34363, 34542, 34721, 34900, 35079, 35258, 35437, 35616, 35795, 35974, 36153, 36332, 36511, 36690, 36869, 37048, 37227, 37406, 37585, 37764, 37943, 38122, 38301, 38480, 38659, 38838, 39017, 39196, 39375, 39670, 39905, 40101, 40286, 40488, 40713, 40894, 41129, 41345, 41575, 41860, 42041, 42378, 42553, 42804, 42975, 43147, 43321, 43496, 43675, 43858, 44030, 44207, 44378, 44557, 44736, 44915, 45103, 45282, 45461, 45645, 45829, 45985, 46137, 46289, 46441, 46593, 46754, 46906]
# done

# %%
import json

i = 0
for key, val in frames.items():
    i += 1
    print(key, ':', val)
    
    if i > 1000:
        break
# Out:
# 2678 : {'transform': [1.15220642089844, 0.0, 0.0, 1.7481689453125, 4.4, -262.5], 'children': [2182]}
# 2677 : {'children': [2678]}
# 2676 : {'children': [2677]}
# 2675 : {'children': [2676]}
# 2679 : {'filter': {'multiply': [1.0, 1.0, 1.0, 0.2109375], 'shift': [0.0, 0.0, 0.0, 0.0]}, 'transform': [1.0, 0.0, 0.0, 1.0, -8.05, 146.5], 'children': [2675]}
# 2674 : {'children': [2679]}
# 2673 : {'children': [2674]}
# 2672 : {'children': []}
# 2671 : {'children': [2672]}
# 2670 : {'children': []}
# 2669 : {'children': [2670]}
# 2667 : {'children': []}
# 2666 : {'children': [2667]}
# 2665 : {'children': [84]}
# 2664 : {'children': [2665]}
# 2663 : {'children': [2664]}
# 2662 : {'children': [2666, 2663]}
# 2668 : {'transform': [-0.863616943359375, -0.045013427734375, -0.0889129638671875, 0.992431640625, 1.6, -94.8], 'children': [2662]}
# 2661 : {'children': [2668]}
# 2660 : {'children': [2661]}
# 2658 : {'children': [65]}
# 2657 : {'children': [2658]}
# 2656 : {'children': [2657]}
# 2655 : {'children': [2656]}
# 2659 : {'transform': [-0.998947143554688, -0.0265045166015625, -0.0265045166015625, 0.998947143554688, -37.85, 5.1], 'children': [2655]}
# 2654 : {'children': [2659]}
# 2653 : {'children': [2654]}
# 2651 : {'children': []}
# 2650 : {'children': [2651]}
# 2648 : {'transform': [1.0, 0.0, 0.0, 1.15299987792969, 0.0, 0.1], 'children': [58]}
# 2647 : {'children': [2648]}
# 2646 : {'children': [2647]}
# 2645 : {'transform': [1.0, 0.0, 0.0, 1.15299987792969, 0.0, 0.1], 'children': [49]}
# 2644 : {'children': [2645]}
# 2643 : {'children': [2644]}
# 2642 : {'children': [2646, 2643]}
# 2649 : {'transform': [0.940216064453125, -0.332427978515625, 0.332427978515625, 0.940216064453125, -1.25, 0.25], 'children': [2642]}
# 2641 : {'children': [2649]}
# 2640 : {'children': [2641]}
# 2639 : {'children': []}
# 2638 : {'children': [2639]}
# 2637 : {'children': []}
# 2636 : {'children': [2637]}
# 2635 : {'children': [2650, 2640, 2638, 2636]}
# 2652 : {'transform': [0.0801849365234375, 0.863006591796875, 0.917709350585938, -0.119232177734375, 34.6, 33.75], 'children': [2635]}
# 2634 : {'children': [2652]}
# 2633 : {'children': [2634]}
# 2632 : {'children': []}
# 2631 : {'children': [2632]}
# 2630 : {'children': []}
# 2629 : {'children': [2630]}
# 2607 : {'children': [12]}
# 2606 : {'children': [2607]}
# 2605 : {'children': [2606]}
# 2604 : {'children': [2605]}
# 2608 : {'transform': [1.0, 0.0, 0.0, 1.0, 17.6, 127.9], 'children': [2604]}
# 2603 : {'children': [2608]}
# 2602 : {'children': [2603]}
# 2600 : {'children': [89]}
# 2599 : {'children': [2600]}
# 2598 : {'children': [2599]}
# 2597 : {'children': [2598]}
# 2601 : {'transform': [1.0, 0.0, 0.0, 1.0, 5.05, 57.05], 'children': [2597]}
# 2596 : {'children': [2601]}
# 2595 : {'children': [2596]}
# 2593 : {'children': [98]}
# 2592 : {'children': [2593]}
# 2591 : {'children': [2592]}
# 2590 : {'children': [94]}
# 2589 : {'children': [2590]}
# 2588 : {'children': [2589]}
# 2587 : {'children': [2591, 2588]}
# 2594 : {'transform': [1.0, 0.0, 0.0, 1.0, 8.7, 62.65], 'children': [2587]}
# 2586 : {'children': [2594]}
# 2585 : {'children': [2586]}
# 2583 : {'children': []}
# 2582 : {'children': [2583]}
# 2581 : {'children': [101]}
# 2580 : {'children': [2581]}
# 2579 : {'children': [2580]}
# 2578 : {'children': [2582, 2579]}
# 2584 : {'transform': [1.0, 0.0, -0.0095977783203125, 1.0159912109375, 5.95, -9.8], 'children': [2578]}
# 2577 : {'children': [2584]}
# 2576 : {'children': [2577]}
# 2574 : {'children': [88]}
# 2573 : {'children': [2574]}
# 2572 : {'children': [2573]}
# 2571 : {'children': [2572]}
# 2575 : {'transform': [1.0, 0.0, 0.0, 1.0, 5.05, 57.05], 'children': [2571]}
# 2570 : {'children': [2575]}
# 2569 : {'children': [2570]}
# 2563 : {'transform': [-0.442794799804688, 0.049713134765625, 0.0098876953125, 0.350875854492188, 635.3, -370.7], 'children': [110]}
# 2562 : {'children': [2563]}
# 2565 : {'transform': [-0.442794799804688, 0.049713134765625, 0.0098876953125, 0.350875854492188, 665.4, -370.95], 'children': [111]}
# 2564 : {'children': [2565]}
# 2567 : {'transform': [-0.442794799804688, 0.049713134765625, 0.0098876953125, 0.350875854492188, 649.6, -357.3], 'children': [112]}
# 2566 : {'children': [2567]}
# 2561 : {'children': [2562, 2564, 2566]}
# 2560 : {'children': [2561]}
# 2559 : {'children': [2560]}
# 2558 : {'children': [2559]}
# 2568 : {'transform': [0.381912231445312, -0.06939697265625, 0.119537353515625, 0.862457275390625, 7.3, 13.15], 'children': [2558]}
# 2557 : {'children': [2568]}
# 2556 : {'children': [2557]}
# 2555 : {'children': []}
# 2554 : {'children': [2555]}
# 2553 : {'children': [2602, 2595, 2585, 2576, 2569, 2556, 2554]}
# 2628 : {'transform': [-0.995040893554688, 0.0962677001953125, 0.087493896484375, 0.904434204101562, -22.5, 11.35], 'children': [2553]}
# 2627 : {'children': [2628]}
# 2626 : {'children': [2627]}
# 2624 : {'children': [123]}
# 2623 : {'children': [2624]}
# 2622 : {'children': [2623]}
# 2621 : {'children': [2622]}
# 2625 : {'transform': [-0.969390869140625, 0.11297607421875, 0.0982208251953125, 1.01515197753906, -1.75, 27.3], 'children': [2621]}
# 2620 : {'children': [2625]}
# 2619 : {'children': [2620]}
# 2617 : {'children': []}
# 2616 : {'children': [2617]}
# 2615 : {'children': [136]}
# 2614 : {'children': [2615]}
# 2613 : {'children': [2614]}
# 2612 : {'children': [2616, 2613]}
# 2618 : {'transform': [-0.930587768554688, 0.30841064453125, 0.30657958984375, 0.950668334960938, 1.05, 13.85], 'children': [2612]}
# 2611 : {'children': [2618]}
# 2610 : {'children': [2611]}
# 2609 : {'transform': [-0.995040893554688, 0.0962677001953125, 0.0962677001953125, 0.995040893554688, -37.1, 8.5], 'children': [2553]}
# 2552 : {'children': [2609]}
# 2551 : {'children': [2552]}
# 2549 : {'children': [2179]}
# 2548 : {'children': [2549]}
# 2547 : {'children': [2548]}
# 2546 : {'children': [2547]}
# 2550 : {'transform': [-0.992462158203125, 0.118560791015625, 0.118560791015625, 0.992462158203125, -23.05, 41.6], 'children': [2546]}
# 2545 : {'children': [2550]}
# 2544 : {'children': [2545]}
# 2541 : {'children': [8]}
# 2540 : {'children': [2541]}
# 2539 : {'children': [2540]}
# 2538 : {'children': [2539]}
# 2542 : {'transform': [1.0, 0.0, 0.0, 1.0, 2.2, 86.4], 'children': [2538]}
# 2537 : {'children': [2542]}
# 2536 : {'children': [2537]}
# 2534 : {'children': []}
# 2533 : {'children': [2534]}
# 2532 : {'children': [39]}
# 2531 : {'children': [2532]}
# 2530 : {'children': [2531]}
# 2529 : {'children': [2533, 2530]}
# 2535 : {'transform': [0.999969482421875, -0.0043792724609375, -0.001129150390625, 1.0, 0.15, 0.35], 'children': [2529]}
# 2528 : {'children': [2535]}
# 2527 : {'children': [2528]}
# 2526 : {'children': []}
# 2525 : {'children': [2526]}
# 2524 : {'children': []}
# 2523 : {'children': [2524]}
# 2522 : {'children': [2536, 2527, 2525, 2523]}
# 2543 : {'transform': [-1.0, 0.0, -0.0052032470703125, 1.00003051757812, 4.7, 52.05], 'children': [2522]}
# 2521 : {'children': [2543]}
# 2520 : {'children': [2521]}
# 2518 : {'children': []}
# 2517 : {'children': [2518]}
# 2515 : {'children': [163]}
# 2514 : {'children': [2515]}
# 2513 : {'children': [2514]}
# 2512 : {'children': [2513]}
# 2516 : {'transform': [-0.916336059570312, -0.394378662109375, -0.394378662109375, 0.916336059570312, 27.25, -28.05], 'children': [2512]}
# 2511 : {'children': [2516]}
# 2510 : {'children': [2511]}
# 2509 : {'children': []}
# 2508 : {'children': [2509]}
# 2507 : {'children': []}
# 2506 : {'children': [2507]}
# 2504 : {'children': [2174]}
# 2503 : {'children': [2504]}
# 2502 : {'children': [2503]}
# 2501 : {'children': [2502]}
# 2505 : {'transform': [-1.0, -0.0224761962890625, 0.0, 1.0, 9.3, -16.65], 'children': [2501]}
# 2500 : {'children': [2505]}
# 2499 : {'children': [2500]}
# 2498 : {'children': []}
# 2497 : {'children': [2498]}
# 2496 : {'children': []}
# 2495 : {'children': [2496]}
# 2494 : {'children': []}
# 2493 : {'children': [2494]}
# 2478 : {'children': [2169]}
# 2477 : {'children': [2478]}
# 2476 : {'children': [2477]}
# 2475 : {'children': []}
# 2474 : {'children': [2475]}
# 2473 : {'children': [2476, 2474]}
# 2479 : {'transform': [0.287216186523438, -0.0013885498046875, 0.021820068359375, 0.9632568359375, 48.95, -11.25], 'children': [2473]}
# 2472 : {'children': [2479]}
# 2471 : {'children': [2472]}
# 2480 : {'children': [2471]}
# 2492 : {'transform': [0.287216186523438, -0.0013885498046875, 0.021820068359375, 0.9632568359375, 48.95, -11.25], 'children': [2473]}
# 2491 : {'children': [2492]}
# 2490 : {'children': [2491]}
# 2466 : {'children': [2166]}
# 2465 : {'children': [2466]}
# 2464 : {'children': [2465]}
# 2463 : {'children': [2164]}
# 2462 : {'children': [2463]}
# 2461 : {'children': [2462]}
# 2460 : {'children': [2162]}
# 2459 : {'children': [2460]}
# 2458 : {'children': [2459]}
# 2457 : {'children': []}
# 2456 : {'children': [2457]}
# 2455 : {'children': [2464, 2461, 2458, 2456]}
# 2489 : {'transform': [-0.328277587890625, -0.0022125244140625, -0.047454833984375, 0.727432250976562, 46.9, -5.55], 'children': [2455]}
# 2488 : {'children': [2489]}
# 2487 : {'children': [2488]}
# 2451 : {'children': [2161]}
# 2450 : {'children': [2451]}
# 2449 : {'children': [2450]}
# 2448 : {'children': [2449]}
# 2486 : {'transform': [-0.313751220703125, -0.130050659179688, -0.125015258789062, 0.576568603515625, 46.75, -4.2], 'children': [2448]}
# 2485 : {'children': [2486]}
# 2484 : {'children': [2485]}
# 2444 : {'children': [2160]}
# 2443 : {'children': [2444]}
# 2442 : {'children': [2443]}
# 2441 : {'children': [2442]}
# 2483 : {'transform': [-0.3939208984375, -0.249603271484375, -0.118606567382812, 0.656356811523438, 45.2, -10.55], 'children': [2441]}
# 2482 : {'children': [2483]}
# 2481 : {'children': [2482]}
# 2680 : {'mask': 2480, 'children': [2490, 2487, 2484, 2481]}
# 2436 : {'children': [2153]}
# 2435 : {'children': [2436]}
# 2434 : {'children': [2435]}
# 2433 : {'children': []}
# 2432 : {'children': [2433]}
# 2431 : {'children': [2434, 2432]}
# 2437 : {'transform': [-0.999984741210938, 1.52587890625e-05, 0.0, 0.999984741210938, 4.75, -12.25], 'children': [2431]}
# 2430 : {'children': [2437]}
# 2429 : {'children': [2430]}
# 2438 : {'children': [2429]}
# 2470 : {'transform': [-0.999984741210938, 1.52587890625e-05, 0.0, 0.999984741210938, 4.75, -12.25], 'children': [2431]}
# 2469 : {'children': [2470]}
# 2468 : {'children': [2469]}
# 2467 : {'transform': [0.589889526367188, -0.020294189453125, 0.073760986328125, 0.758499145507812, 13.6, -6.8], 'children': [2455]}
# 2454 : {'children': [2467]}
# 2453 : {'children': [2454]}
# 2452 : {'transform': [-0.596832275390625, -0.138107299804688, -0.159149169921875, 0.697555541992188, 15.35, -5.8], 'children': [2448]}
# 2447 : {'children': [2452]}
# 2446 : {'children': [2447]}
# 2445 : {'transform': [-0.78961181640625, -0.0316009521484375, -0.0316009521484375, 0.78961181640625, 11.35, -10.35], 'children': [2441]}
# 2440 : {'children': [2445]}
# 2439 : {'children': [2440]}
# 2681 : {'mask': 2438, 'children': [2468, 2453, 2446, 2439]}
# 2428 : {'children': []}
# 2427 : {'children': [2428]}
# 2425 : {'children': []}
# 2424 : {'children': [2425]}
# 2423 : {'children': [2089]}
# 2422 : {'children': [2423]}
# 2421 : {'children': [2422]}
# 2420 : {'children': []}
# 2419 : {'children': [2420]}
# 2418 : {'children': []}
# 2417 : {'children': [2418]}
# 2416 : {'children': [2424, 2421, 2419, 2417]}
# 2426 : {'transform': [0.287200927734375, -0.0013885498046875, 0.0333404541015625, 0.9632568359375, 49.7, -11.2], 'children': [2416]}
# 2415 : {'children': [2426]}
# 2414 : {'children': [2415]}
# 2412 : {'children': []}
# 2411 : {'children': [2412]}
# 2410 : {'children': [1406]}
# 2409 : {'children': [2410]}
# 2408 : {'children': [2409]}
# 2407 : {'children': []}
# 2406 : {'children': [2407]}
# 2405 : {'children': []}
# 2404 : {'children': [2405]}
# 2403 : {'children': [2411, 2408, 2406, 2404]}
# 2413 : {'transform': [-0.999984741210938, 0.0103759765625, 0.0, 0.999984741210938, 4.75, -11.95], 'children': [2403]}
# 2402 : {'children': [2413]}
# 2401 : {'children': [2402]}
# 2399 : {'children': [1213]}
# 2398 : {'children': [2399]}
# 2397 : {'children': [2398]}
# 2395 : {'children': [1167]}
# 2394 : {'children': [2395]}
# 2393 : {'children': [2394]}
# 2388 : {'children': [1148]}
# 2387 : {'children': [2388]}
# 2390 : {'children': [1149]}
# 2389 : {'children': [2390]}
# 2392 : {'transform': [0.707565307617188, 1.07510375976562, -0.76275634765625, 0.251327514648438, -27.15, -8.5], 'children': [1150]}
# 2391 : {'children': [2392]}
# 2386 : {'children': [2387, 2389, 2391]}
# 2385 : {'children': [2386]}
# 2384 : {'children': []}
# 2383 : {'children': [2384]}
# 2382 : {'children': [2393, 2385, 2383]}
# 2396 : {'transform': [1.0, 0.0, 0.0, 1.0, 0.05, -0.05], 'children': [2382]}
# 2381 : {'children': [2396]}
# 2380 : {'children': [2381]}
# 2379 : {'children': [1210]}
# 2378 : {'children': [2379]}
# 2377 : {'children': [2378]}
# 2376 : {'children': [2377]}
# 2375 : {'children': [2397, 2380, 2376]}
# 2400 : {'transform': [-1.0, -1.52587890625e-05, 0.082061767578125, 1.0, -14.55, -15.35], 'children': [2375]}
# 2374 : {'children': [2400]}
# 2373 : {'children': [2374]}
# 2362 : {'children': [1176]}
# 2361 : {'children': [2362]}
# 2360 : {'children': [2361]}
# 2363 : {'children': [2360]}
# 2371 : {'children': [1192]}
# 2370 : {'children': [2371]}
# 2369 : {'children': [2370]}
# 2366 : {'children': [1185]}
# 2368 : {'children': [1186]}
# 2367 : {'children': [2368]}
# 2365 : {'children': [2366, 2367]}
# 2364 : {'children': [2365]}
# 2682 : {'mask': 2363, 'children': [2369, 2364]}
# 2358 : {'children': []}
# 2357 : {'children': [2358]}
# 2352 : {'transform': [0.952590942382812, 0.617721557617188, -0.333892822265625, 0.661407470703125, -22.1, 0.9], 'children': [1136]}
# 2351 : {'children': [2352]}
# 2354 : {'transform': [0.829910278320312, 0.633392333984375, -0.529632568359375, 0.915878295898438, -22.65, 5.85], 'children': [1137]}
# 2353 : {'children': [2354]}
# 2356 : {'transform': [1.02830505371094, 1.23773193359375, -0.84808349609375, 0.2056884765625, -34.35, -11.55], 'children': [1138]}
# 2355 : {'children': [2356]}
# 2350 : {'children': [2351, 2353, 2355]}
# 2349 : {'children': [2350]}
# 2348 : {'children': []}
# 2347 : {'children': [2348]}
# 2346 : {'children': [2357, 2349, 2347]}
# 2359 : {'transform': [0.801620483398438, 0.0599365234375, -0.100387573242188, 0.995025634765625, -26.6, 0.3], 'children': [2346]}
# 2345 : {'children': [2359]}
# 2344 : {'children': [2345]}
# 2343 : {'children': [3237, 2344]}
# 2372 : {'transform': [0.944381713867188, -0.118316650390625, 0.123870849609375, 0.988800048828125, 80.35, -20.15], 'children': [2343]}
# 2342 : {'children': [2372]}
# 2341 : {'children': [2342]}
# 2340 : {'children': []}
# 2339 : {'children': [2340]}
# 2338 : {'children': []}
# 2337 : {'children': [2338]}
# 2334 : {'children': [789]}
# 2333 : {'children': [2334]}
# 2332 : {'children': [2333]}
# 2331 : {'children': [2332]}
# 2335 : {'transform': [1.0, 0.0, 0.0, 1.0, -23.05, -13.6], 'children': [2331]}
# 2330 : {'children': [2335]}
# 2329 : {'children': [2330]}
# 2328 : {'children': [869]}
# 2327 : {'children': [2328]}
# 2326 : {'children': [2327]}
# 2325 : {'children': []}
# 2324 : {'children': [2325]}
# 2323 : {'children': [814]}
# 2322 : {'children': [2323]}
# 2321 : {'children': [2322]}
# 2320 : {'children': []}
# 2319 : {'children': [2320]}
# 2318 : {'children': []}
# 2317 : {'children': [2318]}
# 2316 : {'children': [2329, 2326, 2324, 2321, 2319, 2317]}
# 2336 : {'transform': [-1.0, 0.0, 0.12359619140625, 1.0, 22.3, 18.45], 'children': [2316]}
# 2315 : {'children': [2336]}
# 2314 : {'children': [2315]}
# 2311 : {'children': [640]}
# 2310 : {'children': [2311]}
# 2309 : {'children': [2310]}
# 2308 : {'children': [2309]}
# 2312 : {'transform': [1.0, 0.0, 0.0, 1.0, -26.05, -0.45], 'children': [2308]}
# 2307 : {'children': [2312]}
# 2306 : {'children': [2307]}
# 2305 : {'children': [2306]}
# 2313 : {'transform': [-1.0, 0.0, -0.003814697265625, 1.0, 22.2, 18.45], 'children': [2305]}
# 2304 : {'children': [2313]}
# 2303 : {'children': [2304]}
# 2302 : {'children': []}
# 2301 : {'children': [2302]}
# 2300 : {'children': []}
# 2299 : {'children': [2300]}
# 2298 : {'children': []}
# 2297 : {'children': [2298]}
# 2296 : {'children': []}
# 2295 : {'children': [2296]}
# 2293 : {'transform': [1.0, 0.0, 0.0, 1.0, 69.45, 9.2], 'children': [309]}
# 2292 : {'children': [2293]}
# 2291 : {'children': [2292]}
# 2290 : {'children': [2291]}
# 2294 : {'transform': [-0.9789123535156249, -0.0652313232421874, -0.04260253906250014, 1.04130554199219, 82.95, -45.4], 'children': [2290]}
# 2289 : {'children': [2294]}
# 2288 : {'children': [2289]}
# 2286 : {'children': [310]}
# 2285 : {'children': [2286]}
# 2284 : {'children': [2285]}
# 2283 : {'children': [2284]}
# 2287 : {'transform': [-0.972763061523438, -0.06481933593749979, -0.04260253906250008, 1.04130554199219, 17.35, -51.6], 'children': [2283]}
# 2282 : {'children': [2287]}
# 2281 : {'children': [2282]}
# 2279 : {'children': [236]}
# 2278 : {'children': [2279]}
# 2277 : {'children': [2278]}
# 2276 : {'children': [2277]}
# 2280 : {'transform': [-0.972763061523438, -0.06481933593749979, -0.04260253906250008, 1.04130554199219, 49.05, -35.85], 'children': [2276]}
# 2275 : {'children': [2280]}
# 2274 : {'children': [2275]}
# 2273 : {'transform': [1.0, 0.0, 0.0, 1.0, 0.85, 0.0], 'children': [383]}
# 2272 : {'children': [2273]}
# 2271 : {'children': [2272]}
# 2269 : {'children': []}
# 2268 : {'children': [2269]}
# 2267 : {'children': [230]}
# 2266 : {'children': [2267]}
# 2265 : {'children': [2266]}
# 2264 : {'children': [2268, 2265]}
# 2270 : {'transform': [-0.86334228515625, -0.13755798339843803, -0.15727233886718786, 0.987045288085938, -48.75, -17.6], 'children': [2264]}
# 2263 : {'children': [2270]}
# 2262 : {'children': [2263]}
# 2261 : {'children': [193]}
# 2260 : {'children': [2261]}
# 2259 : {'children': [2260]}
# 2258 : {'children': []}
# 2257 : {'children': [2258]}
# 2255 : {'children': []}
# 2254 : {'children': [2255]}
# 2253 : {'children': []}
# 2252 : {'children': [2253]}
# 2251 : {'children': [168]}
# 2250 : {'children': [2251]}
# 2249 : {'children': [2250]}
# 2248 : {'children': [2254, 2252, 2249]}
# 2256 : {'transform': [-0.7800140380859382, -0.622802734375, -0.577407836914062, 0.7231750488281251, 30.1, -47.7], 'children': [2248]}
# 2247 : {'children': [2256]}
# 2246 : {'children': [2247]}
# 2244 : {'children': [155]}
# 2243 : {'children': [2244]}
# 2242 : {'children': [2243]}
# 2241 : {'children': [2242]}
# 2245 : {'transform': [-0.965927124023438, 0.258819580078125, 0.258819580078125, 0.965927124023438, -29.15, -29.55], 'children': [2241]}
# 2240 : {'children': [2245]}
# 2239 : {'children': [2240]}
# 2238 : {'children': []}
# 2237 : {'children': [2238]}
# 2236 : {'children': []}
# 2235 : {'children': [2236]}
# 2234 : {'children': []}
# 2233 : {'children': [2234]}
# 2232 : {'children': [2517, 2510, 2508, 2506, 2499, 2497, 2495, 2493, 2680, 2681, 2427, 2414, 2401, 2373, 2341, 2339, 2337, 2314, 2303, 2301, 2299, 2297, 2295, 2288, 2281, 2274, 2271, 2262, 2259, 2257, 2246, 2239, 2237, 2235, 2233]}
# 2519 : {'transform': [0.994003295898438, -0.0802154541015625, 0.0802154541015625, 0.994003295898438, 30.85, -56.05], 'children': [2232]}
# 2231 : {'children': [2519]}
# 2230 : {'children': [2231]}
# 2229 : {'children': []}
# 2228 : {'children': [2229]}
# 2227 : {'children': []}
# 2226 : {'children': [2227]}
# 2225 : {'children': []}
# 2224 : {'children': [2225]}
# 2223 : {'children': []}
# 2222 : {'children': [2223]}
# 2221 : {'children': []}
# 2220 : {'children': [2221]}
# 2219 : {'children': []}
# 2218 : {'children': [2219]}
# 2215 : {'children': [11]}
# 2214 : {'children': [2215]}
# 2213 : {'children': [2214]}
# 2212 : {'children': [2213]}
# 2216 : {'transform': [0.792190551757812, -0.598312377929688, -0.598312377929688, -0.792190551757812, -40.0, 41.45], 'children': [2212]}
# 2211 : {'children': [2216]}
# 2210 : {'children': [2211]}
# 2209 : {'children': []}
# 2208 : {'children': [2209]}
# 2206 : {'children': [32]}
# 2205 : {'children': [2206]}
# 2204 : {'children': [2205]}
# 2203 : {'children': []}
# 2202 : {'children': [2203]}
# 2201 : {'children': [2204, 2202]}
# 2207 : {'transform': [-0.019378662109375, -0.9931640625, -0.9931640625, 0.019378662109375, 18.5, 44.65], 'children': [2201]}
# 2200 : {'children': [2207]}
# 2199 : {'children': [2200]}
# 2198 : {'children': []}
# 2197 : {'children': [2198]}
# 2196 : {'children': [2210, 2208, 2199, 2197]}
# 2217 : {'transform': [0.0801849365234375, 0.863006591796875, 0.917709350585938, -0.119232177734375, 34.6, 33.75], 'children': [2196]}
# 2195 : {'children': [2217]}
# 2194 : {'children': [2195]}
# 2193 : {'children': []}
# 2192 : {'children': [2193]}
# 2191 : {'children': []}
# 2190 : {'children': [2191]}
# 2189 : {'children': []}
# 2188 : {'children': [2189]}
# 2187 : {'children': []}
# 2186 : {'children': [2187]}
# 2185 : {'children': []}
# 2184 : {'children': [2185]}
# 2183 : {'children': [2673, 2671, 2669, 2660, 2653, 2633, 2631, 2629, 2626, 2619, 2610, 2551, 2544, 2520, 2230, 2228, 2226, 2224, 2222, 2220, 2218, 2194, 2192, 2190, 2188, 2186, 2184]}
# 2864 : {'filter': {'multiply': [1.0, 1.0, 1.0, 0.2109375], 'shift': [0.0, 0.0, 0.0, 0.0]}, 'transform': [1.0, 0.0, 0.0, 1.0, -8.05, 146.5], 'children': [2675]}
# 2863 : {'children': [2864]}
# 2862 : {'children': [2863]}
# 2861 : {'children': []}
# 2860 : {'children': [2861]}
# 2859 : {'children': []}
# 2858 : {'children': [2859]}
# 2857 : {'transform': [-0.863616943359375, -0.045013427734375, -0.0889129638671875, 0.992431640625, 1.6, -94.8], 'children': [2662]}
# 2856 : {'children': [2857]}
# 2855 : {'children': [2856]}
# 2854 : {'transform': [-0.998947143554688, -0.0265045166015625, -0.0265045166015625, 0.998947143554688, -37.85, 5.1], 'children': [2655]}
# 2853 : {'children': [2854]}
# 2852 : {'children': [2853]}
# 2851 : {'transform': [0.0801849365234375, 0.863006591796875, 0.917709350585938, -0.119232177734375, 34.6, 33.75], 'children': [2635]}
# 2850 : {'children': [2851]}
# 2849 : {'children': [2850]}
# 2848 : {'children': []}
# 2847 : {'children': [2848]}
# 2846 : {'children': []}
# 2845 : {'children': [2846]}
# 2844 : {'transform': [-0.995040893554688, 0.0962677001953125, 0.087493896484375, 0.904434204101562, -22.5, 11.35], 'children': [2553]}
# 2843 : {'children': [2844]}
# 2842 : {'children': [2843]}
# 2841 : {'transform': [-0.969390869140625, 0.11297607421875, 0.0982208251953125, 1.01515197753906, -1.75, 27.3], 'children': [2621]}
# 2840 : {'children': [2841]}
# 2839 : {'children': [2840]}
# 2838 : {'transform': [-0.930587768554688, 0.30841064453125, 0.30657958984375, 0.950668334960938, 1.05, 13.85], 'children': [2612]}
# 2837 : {'children': [2838]}
# 2836 : {'children': [2837]}
# 2835 : {'transform': [-0.995040893554688, 0.0962677001953125, 0.0962677001953125, 0.995040893554688, -37.1, 8.5], 'children': [2553]}
# 2834 : {'children': [2835]}
# 2833 : {'children': [2834]}
# 2832 : {'transform': [-0.992462158203125, 0.118560791015625, 0.118560791015625, 0.992462158203125, -23.05, 41.6], 'children': [2546]}
# 2831 : {'children': [2832]}
# 2830 : {'children': [2831]}
# 2829 : {'transform': [-1.0, 0.0, -0.0052032470703125, 1.00003051757812, 4.7, 52.05], 'children': [2522]}
# 2828 : {'children': [2829]}
# 2827 : {'children': [2828]}
# 2825 : {'children': []}
# 2824 : {'children': [2825]}
# 2823 : {'transform': [-0.916336059570312, -0.394378662109375, -0.394378662109375, 0.916336059570312, 27.25, -28.05], 'children': [2512]}
# 2822 : {'children': [2823]}
# 2821 : {'children': [2822]}
# 2820 : {'children': []}
# 2819 : {'children': [2820]}
# 2818 : {'children': []}
# 2817 : {'children': [2818]}
# 2816 : {'transform': [-1.0, -0.0224761962890625, 0.0, 1.0, 9.3, -16.65], 'children': [2501]}
# 2815 : {'children': [2816]}
# 2814 : {'children': [2815]}
# 2813 : {'children': []}
# 2812 : {'children': [2813]}
# 2811 : {'children': []}
# 2810 : {'children': [2811]}
# 2809 : {'children': []}
# 2808 : {'children': [2809]}
# 2794 : {'transform': [0.287216186523438, -0.0013885498046875, 0.021820068359375, 0.9632568359375, 48.95, -11.25], 'children': [2473]}
# 2793 : {'children': [2794]}
# 2792 : {'children': [2793]}
# 2795 : {'children': [2792]}
# 2807 : {'transform': [0.287216186523438, -0.0013885498046875, 0.021820068359375, 0.9632568359375, 48.95, -11.25], 'children': [2473]}
# 2806 : {'children': [2807]}
# 2805 : {'children': [2806]}
# 2804 : {'transform': [-0.328277587890625, -0.0022125244140625, -0.047454833984375, 0.727432250976562, 46.9, -5.55], 'children': [2455]}
# 2803 : {'children': [2804]}
# 2802 : {'children': [2803]}
# 2801 : {'transform': [-0.313751220703125, -0.130050659179688, -0.125015258789062, 0.576568603515625, 46.75, -4.2], 'children': [2448]}
# 2800 : {'children': [2801]}
# 2799 : {'children': [2800]}
# 2798 : {'transform': [-0.3939208984375, -0.249603271484375, -0.118606567382812, 0.656356811523438, 45.2, -10.55], 'children': [2441]}
# 2797 : {'children': [2798]}
# 2796 : {'children': [2797]}
# 2865 : {'mask': 2795, 'children': [2805, 2802, 2799, 2796]}
# 2778 : {'transform': [-0.999984741210938, 1.52587890625e-05, 0.0, 0.999984741210938, 4.75, -12.25], 'children': [2431]}
# 2777 : {'children': [2778]}
# 2776 : {'children': [2777]}
# 2779 : {'children': [2776]}
# 2791 : {'transform': [-0.999984741210938, 1.52587890625e-05, 0.0, 0.999984741210938, 4.75, -12.25], 'children': [2431]}
# 2790 : {'children': [2791]}
# 2789 : {'children': [2790]}
# 2788 : {'transform': [0.589889526367188, -0.020294189453125, 0.073760986328125, 0.758499145507812, 13.6, -6.8], 'children': [2455]}
# 2787 : {'children': [2788]}
# 2786 : {'children': [2787]}
# 2785 : {'transform': [-0.596832275390625, -0.138107299804688, -0.159149169921875, 0.697555541992188, 15.35, -5.8], 'children': [2448]}
# 2784 : {'children': [2785]}
# 2783 : {'children': [2784]}
# 2782 : {'transform': [-0.78961181640625, -0.0316009521484375, -0.0316009521484375, 0.78961181640625, 11.35, -10.35], 'children': [2441]}
# 2781 : {'children': [2782]}
# 2780 : {'children': [2781]}
# 2866 : {'mask': 2779, 'children': [2789, 2786, 2783, 2780]}
# 2775 : {'children': []}
# 2774 : {'children': [2775]}
# 2773 : {'transform': [0.287200927734375, -0.0013885498046875, 0.0333404541015625, 0.9632568359375, 49.7, -11.2], 'children': [2416]}
# 2772 : {'children': [2773]}
# 2771 : {'children': [2772]}
# 2770 : {'transform': [-0.999984741210938, 0.0103759765625, 0.0, 0.999984741210938, 4.75, -11.95], 'children': [2403]}
# 2769 : {'children': [2770]}
# 2768 : {'children': [2769]}
# 2767 : {'transform': [-1.0, -1.52587890625e-05, 0.082061767578125, 1.0, -14.55, -15.35], 'children': [2375]}
# 2766 : {'children': [2767]}
# 2765 : {'children': [2766]}
# 2867 : {'mask': 2363, 'children': [2369, 2364]}
# 2764 : {'transform': [0.944381713867188, -0.118316650390625, 0.123870849609375, 0.988800048828125, 80.35, -20.15], 'children': [2343]}
# 2763 : {'children': [2764]}
# 2762 : {'children': [2763]}
# 2761 : {'children': []}
# 2760 : {'children': [2761]}
# 2759 : {'children': []}
# 2758 : {'children': [2759]}
# 2757 : {'transform': [-1.0, 0.0, 0.12359619140625, 1.0, 22.3, 18.45], 'children': [2316]}
# 2756 : {'children': [2757]}
# 2755 : {'children': [2756]}
# 2754 : {'transform': [-1.0, 0.0, -0.003814697265625, 1.0, 22.2, 18.45], 'children': [2305]}
# 2753 : {'children': [2754]}
# 2752 : {'children': [2753]}
# 2751 : {'children': []}
# 2750 : {'children': [2751]}
# 2749 : {'children': []}
# 2748 : {'children': [2749]}
# 2747 : {'children': []}
# 2746 : {'children': [2747]}
# 2745 : {'children': []}
# 2744 : {'children': [2745]}
# 2743 : {'transform': [-0.9789123535156249, -0.0660269715619322, -0.04260253906250014, 1.0412814276608264, 82.94999999999999, -45.28055555555555], 'children': [2290]}
# 2742 : {'children': [2743]}
# 2741 : {'children': [2742]}
# 2740 : {'transform': [-0.972763061523438, -0.06560990826789434, -0.04260253906250008, 1.0412812921248453, 17.35, -51.53472222222222], 'children': [2283]}
# 2739 : {'children': [2740]}
# 2738 : {'children': [2739]}
# 2737 : {'transform': [-0.9727808634331251, -0.06437793283479426, -0.04260253956011066, 1.0413088146252585, 49.05138888888889, -35.88472222222222], 'children': [2276]}
# 2736 : {'children': [2737]}
# 2735 : {'children': [2736]}
# 2734 : {'transform': [1.0, 0.0, 0.0, 1.0, 0.85, 0.0], 'children': [383]}
# 2733 : {'children': [2734]}
# 2732 : {'children': [2733]}
# 2731 : {'transform': [-0.8632014891451297, -0.1382305727649516, -0.15804005955654207, 0.9868827801946422, -48.725, -17.65], 'children': [2264]}
# 2730 : {'children': [2731]}
# 2729 : {'children': [2730]}
# 2728 : {'children': [193]}
# 2727 : {'children': [2728]}
# 2726 : {'children': [2727]}
# 2725 : {'children': []}
# 2724 : {'children': [2725]}
# 2723 : {'transform': [-0.7800140380859382, -0.622802734375, -0.577407836914062, 0.7231750488281251, 30.059722222222224, -47.67777777777778], 'children': [2248]}
# 2722 : {'children': [2723]}
# 2721 : {'children': [2722]}
# 2720 : {'transform': [-0.965927124023438, 0.258819580078125, 0.258819580078125, 0.965927124023438, -29.15, -29.55], 'children': [2241]}
# 2719 : {'children': [2720]}
# 2718 : {'children': [2719]}
# 2717 : {'children': []}
# 2716 : {'children': [2717]}
# 2715 : {'children': []}
# 2714 : {'children': [2715]}
# 2713 : {'children': []}
# 2712 : {'children': [2713]}
# 2711 : {'children': [2824, 2821, 2819, 2817, 2814, 2812, 2810, 2808, 2865, 2866, 2774, 2771, 2768, 2765, 2762, 2760, 2758, 2755, 2752, 2750, 2748, 2746, 2744, 2741, 2738, 2735, 2732, 2729, 2726, 2724, 2721, 2718, 2716, 2714, 2712]}
# 2826 : {'transform': [0.994003295898438, -0.0802154541015625, 0.0802154541015625, 0.994003295898438, 30.85, -56.05], 'children': [2711]}
# 2710 : {'children': [2826]}
# 2709 : {'children': [2710]}
# 2708 : {'children': []}
# 2707 : {'children': [2708]}
# 2706 : {'children': []}
# 2705 : {'children': [2706]}
# 2704 : {'children': []}
# 2703 : {'children': [2704]}
# 2702 : {'children': []}
# 2701 : {'children': [2702]}
# 2700 : {'children': []}
# 2699 : {'children': [2700]}
# 2698 : {'children': []}
# 2697 : {'children': [2698]}
# 2696 : {'transform': [0.0801849365234375, 0.863006591796875, 0.917709350585938, -0.119232177734375, 34.6, 33.75], 'children': [2196]}
# 2695 : {'children': [2696]}
# 2694 : {'children': [2695]}
# 2693 : {'children': []}
# 2692 : {'children': [2693]}
# 2691 : {'children': []}
# 2690 : {'children': [2691]}
# 2689 : {'children': []}
# 2688 : {'children': [2689]}
# 2687 : {'children': []}
# 2686 : {'children': [2687]}
# 2685 : {'children': []}
# 2684 : {'children': [2685]}
# 2683 : {'children': [2862, 2860, 2858, 2855, 2852, 2849, 2847, 2845, 2842, 2839, 2836, 2833, 2830, 2827, 2709, 2707, 2705, 2703, 2701, 2699, 2697, 2694, 2692, 2690, 2688, 2686, 2684]}
# 3049 : {'filter': {'multiply': [1.0, 1.0, 1.0, 0.2109375], 'shift': [0.0, 0.0, 0.0, 0.0]}, 'transform': [1.0, 0.0, 0.0, 1.0, -8.05, 146.5], 'children': [2675]}
# 3048 : {'children': [3049]}
# 3047 : {'children': [3048]}
# 3046 : {'children': []}
# 3045 : {'children': [3046]}
# 3044 : {'children': []}
# 3043 : {'children': [3044]}
# 3042 : {'transform': [-0.863616943359375, -0.04501342773437508, -0.08891296386718749, 0.9924316406250001, 1.6, -94.8], 'children': [2662]}
# 3041 : {'children': [3042]}
# 3040 : {'children': [3041]}
# 3039 : {'transform': [-0.998947143554688, -0.026504516601562427, -0.02650451660156255, 0.998947143554688, -37.85, 5.1], 'children': [2655]}
# 3038 : {'children': [3039]}
# 3037 : {'children': [3038]}
# 3036 : {'transform': [0.0801849365234374, 0.863006591796875, 0.917709350585938, -0.11923217773437507, 34.6, 33.75], 'children': [2635]}
# 3035 : {'children': [3036]}
# 3034 : {'children': [3035]}
# 3033 : {'children': []}
# 3032 : {'children': [3033]}
# 3031 : {'children': []}
# 3030 : {'children': [3031]}
# 3029 : {'transform': [-0.9950408935546882, 0.0962677001953127, 0.08749389648437497, 0.904434204101562, -22.5, 11.35], 'children': [2553]}
# 3028 : {'children': [3029]}
# 3027 : {'children': [3028]}
# 3026 : {'transform': [-0.969390869140625, 0.11297607421875017, 0.09822082519531254, 1.01515197753906, -1.75, 27.3], 'children': [2621]}
# 3025 : {'children': [3026]}
# 3024 : {'children': [3025]}
# 3023 : {'transform': [-0.930587768554688, 0.30841064453125033, 0.30657958984375006, 0.9506683349609379, 1.05, 13.85], 'children': [2612]}
# 3022 : {'children': [3023]}
# 3021 : {'children': [3022]}
# 3020 : {'transform': [-0.995040893554688, 0.0962677001953122, 0.09626770019531251, 0.995040893554688, -37.1, 8.5], 'children': [2553]}
# 3019 : {'children': [3020]}
# 3018 : {'children': [3019]}
# 3017 : {'transform': [-0.992462158203125, 0.11856079101562517, 0.11856079101562504, 0.992462158203125, -23.05, 41.6], 'children': [2546]}
# 3016 : {'children': [3017]}
# 3015 : {'children': [3016]}
# 3014 : {'transform': [-1.0, 2.4460016348747083e-16, -0.005203247070312256, 1.00003051757812, 4.7, 52.05], 'children': [2522]}
# 3013 : {'children': [3014]}
# 3012 : {'children': [3013]}
# 3010 : {'children': []}
# 3009 : {'children': [3010]}
# 3008 : {'transform': [-0.916336059570312, -0.394378662109375, -0.394378662109375, 0.916336059570312, 27.25, -28.05], 'children': [2512]}
# 3007 : {'children': [3008]}
# 3006 : {'children': [3007]}
# 3005 : {'children': []}
# 3004 : {'children': [3005]}
# 3003 : {'children': []}
# 3002 : {'children': [3003]}
# 3001 : {'transform': [-1.0, -0.0224761962890625, 0.0, 1.0, 9.3, -16.65], 'children': [2501]}
# 3000 : {'children': [3001]}
# 2999 : {'children': [3000]}
# 2998 : {'children': []}
# 2997 : {'children': [2998]}
# 2996 : {'children': []}
# 2995 : {'children': [2996]}
# 2994 : {'children': []}
# 2993 : {'children': [2994]}
# 2979 : {'transform': [0.287216186523438, -0.0013885498046875, 0.021820068359375, 0.9632568359375, 48.95, -11.25], 'children': [2473]}
# 2978 : {'children': [2979]}
# 2977 : {'children': [2978]}
# 2980 : {'children': [2977]}
# 2992 : {'transform': [0.287216186523438, -0.0013885498046875, 0.021820068359375, 0.9632568359375, 48.95, -11.25], 'children': [2473]}
# 2991 : {'children': [2992]}
# 2990 : {'children': [2991]}
# 2989 : {'transform': [-0.328277587890625, -0.0022125244140625, -0.047454833984375, 0.727432250976562, 46.9, -5.55], 'children': [2455]}
# 2988 : {'children': [2989]}
# 2987 : {'children': [2988]}
# 2986 : {'transform': [-0.313751220703125, -0.130050659179688, -0.125015258789062, 0.576568603515625, 46.75, -4.2], 'children': [2448]}
# 2985 : {'children': [2986]}
# 2984 : {'children': [2985]}
# 2983 : {'transform': [-0.3939208984375, -0.249603271484375, -0.118606567382812, 0.656356811523438, 45.2, -10.55], 'children': [2441]}
# 2982 : {'children': [2983]}
# 2981 : {'children': [2982]}
# 3050 : {'mask': 2980, 'children': [2990, 2987, 2984, 2981]}
# 2963 : {'transform': [-0.999984741210938, 1.52587890625e-05, 0.0, 0.999984741210938, 4.75, -12.25], 'children': [2431]}
# 2962 : {'children': [2963]}
# 2961 : {'children': [2962]}
# 2964 : {'children': [2961]}
# 2976 : {'transform': [-0.999984741210938, 1.52587890625e-05, 0.0, 0.999984741210938, 4.75, -12.25], 'children': [2431]}
# 2975 : {'children': [2976]}
# 2974 : {'children': [2975]}
# 2973 : {'transform': [0.589889526367188, -0.020294189453125, 0.073760986328125, 0.758499145507812, 13.6, -6.8], 'children': [2455]}
# 2972 : {'children': [2973]}
# 2971 : {'children': [2972]}
# 2970 : {'transform': [-0.596832275390625, -0.138107299804688, -0.159149169921875, 0.697555541992188, 15.35, -5.8], 'children': [2448]}
# 2969 : {'children': [2970]}
# 2968 : {'children': [2969]}
# 2967 : {'transform': [-0.78961181640625, -0.0316009521484375, -0.0316009521484375, 0.78961181640625, 11.35, -10.35], 'children': [2441]}
# 2966 : {'children': [2967]}
# 2965 : {'children': [2966]}
# 3051 : {'mask': 2964, 'children': [2974, 2971, 2968, 2965]}
# 2960 : {'children': []}
# 2959 : {'children': [2960]}
# 2958 : {'transform': [0.287200927734375, -0.0013885498046875, 0.0333404541015625, 0.9632568359375, 49.7, -11.2], 'children': [2416]}
# 2957 : {'children': [2958]}
# 2956 : {'children': [2957]}
# 2955 : {'transform': [-0.999984741210938, 0.0103759765625, 0.0, 0.999984741210938, 4.75, -11.95], 'children': [2403]}
# 2954 : {'children': [2955]}
# 2953 : {'children': [2954]}
# 2952 : {'transform': [-1.0, -1.52587890625e-05, 0.082061767578125, 1.0, -14.55, -15.35], 'children': [2375]}
# 2951 : {'children': [2952]}
# 2950 : {'children': [2951]}
# 3052 : {'mask': 2363, 'children': [2369, 2364]}
# 2949 : {'transform': [0.944381713867188, -0.118316650390625, 0.123870849609375, 0.988800048828125, 80.35, -20.15], 'children': [2343]}
# 2948 : {'children': [2949]}
# 2947 : {'children': [2948]}
# 2946 : {'children': []}
# 2945 : {'children': [2946]}
# 2944 : {'children': []}
# 2943 : {'children': [2944]}
# 2942 : {'transform': [-1.0, 0.0, 0.12359619140625, 1.0, 22.3, 18.45], 'children': [2316]}
# 2941 : {'children': [2942]}
# 2940 : {'children': [2941]}
# 2939 : {'transform': [-1.0, 0.0, -0.003814697265625, 1.0, 22.2, 18.45], 'children': [2305]}
# 2938 : {'children': [2939]}
# 2937 : {'children': [2938]}
# 2936 : {'children': []}
# 2935 : {'children': [2936]}
# 2934 : {'children': []}
# 2933 : {'children': [2934]}
# 2932 : {'children': []}
# 2931 : {'children': [2932]}
# 2930 : {'children': []}
# 2929 : {'children': [2930]}
# 2928 : {'transform': [-0.9789123535156248, -0.06841392157466676, -0.04260253906250013, 1.0412054368607044, 82.95, -44.92222222222222], 'children': [2290]}
# 2927 : {'children': [2928]}
# 2926 : {'children': [2927]}
# 2925 : {'transform': [-0.972763061523438, -0.06798162622392297, -0.04260253906250008, 1.0412049411175957, 17.35, -51.33888888888889], 'children': [2283]}
# 2924 : {'children': [2925]}
# 2923 : {'children': [2924]}
# 2922 : {'transform': [-0.9728342691659204, -0.06305377666629405, -0.04260254088233352, 1.0413175099465755, 49.05555555555555, -35.98888888888889], 'children': [2276]}
# 2921 : {'children': [2922]}
# 2920 : {'children': [2921]}
# 2919 : {'transform': [1.0, 0.0, 0.0, 1.0, 0.85, 0.0], 'children': [383]}
# 2918 : {'children': [2919]}
# 2917 : {'children': [2918]}
# 2916 : {'transform': [-0.8627750054279374, -0.14024738622460506, -0.16034246295404592, 0.986392507941863, -48.650000000000006, -17.8], 'children': [2264]}
# 2915 : {'children': [2916]}
# 2914 : {'children': [2915]}
# 2913 : {'children': [193]}
# 2912 : {'children': [2913]}
# 2911 : {'children': [2912]}
# 2910 : {'children': []}
# 2909 : {'children': [2910]}
# 2908 : {'transform': [-0.7800140380859378, -0.6228027343750002, -0.5774078369140623, 0.7231750488281248, 29.93888888888889, -47.61111111111111], 'children': [2248]}
# 2907 : {'children': [2908]}
# 2906 : {'children': [2907]}
# 2905 : {'transform': [-0.965927124023438, 0.2588195800781247, 0.25881958007812506, 0.9659271240234382, -29.15, -29.55], 'children': [2241]}
# 2904 : {'children': [2905]}
# 2903 : {'children': [2904]}
# 2902 : {'children': []}
# 2901 : {'children': [2902]}
# 2900 : {'children': []}
# 2899 : {'children': [2900]}
# 2898 : {'children': []}
# 2897 : {'children': [2898]}
# 2896 : {'children': [3009, 3006, 3004, 3002, 2999, 2997, 2995, 2993, 3050, 3051, 2959, 2956, 2953, 2950, 2947, 2945, 2943, 2940, 2937, 2935, 2933, 2931, 2929, 2926, 2923, 2920, 2917, 2914, 2911, 2909, 2906, 2903, 2901, 2899, 2897]}
# 3011 : {'transform': [0.994003295898438, -0.0802154541015625, 0.0802154541015625, 0.994003295898438, 30.85, -56.05], 'children': [2896]}
# 2895 : {'children': [3011]}
# 2894 : {'children': [2895]}
# 2893 : {'children': []}
# 2892 : {'children': [2893]}
# 2891 : {'children': []}
# 2890 : {'children': [2891]}
# 2889 : {'children': []}
# 2888 : {'children': [2889]}
# 2887 : {'children': []}
# 2886 : {'children': [2887]}
# 2885 : {'children': []}
# 2884 : {'children': [2885]}
# 2883 : {'children': []}
# 2882 : {'children': [2883]}
# 2881 : {'transform': [0.0801849365234374, 0.863006591796875, 0.917709350585938, -0.11923217773437507, 34.6, 33.75], 'children': [2196]}
# 2880 : {'children': [2881]}
# 2879 : {'children': [2880]}
# 2878 : {'children': []}
# 2877 : {'children': [2878]}
# 2876 : {'children': []}
# 2875 : {'children': [2876]}
# 2874 : {'children': []}
# 2873 : {'children': [2874]}
# 2872 : {'children': []}
# 2871 : {'children': [2872]}
# 2870 : {'children': []}
# 2869 : {'children': [2870]}
# 2868 : {'children': [3047, 3045, 3043, 3040, 3037, 3034, 3032, 3030, 3027, 3024, 3021, 3018, 3015, 3012, 2894, 2892, 2890, 2888, 2886, 2884, 2882, 2879, 2877, 2875, 2873, 2871, 2869]}
# 3234 : {'filter': {'multiply': [1.0, 1.0, 1.0, 0.2109375], 'shift': [0.0, 0.0, 0.0, 0.0]}, 'transform': [1.0, 0.0, 0.0, 1.0, -8.05, 146.5], 'children': [2675]}
# 3233 : {'children': [3234]}
# 3232 : {'children': [3233]}
# 3231 : {'children': []}
# 3230 : {'children': [3231]}
# 3229 : {'children': []}
# 3228 : {'children': [3229]}
# 3227 : {'transform': [-0.8642451831930076, -0.04027344558857509, -0.0728175209599995, 0.9931942669030798, -0.8624999999999998, -95.0625], 'children': [2662]}
# 3226 : {'children': [3227]}
# 3225 : {'children': [3226]}
# 3224 : {'transform': [-0.9986919281458992, -0.03309610725497582, -0.03309610725497594, 0.9986919281458992, -38.5625, 5.05], 'children': [2655]}
# 3223 : {'children': [3224]}
# 3222 : {'children': [3223]}
# 3221 : {'transform': [0.09814668003305957, 0.8603319772427097, 0.9143571872640268, -0.15907135986700593, 33.987500000000004, 33.3], 'children': [2635]}
# 3220 : {'children': [3221]}
# 3219 : {'children': [3220]}
# 3218 : {'children': []}
# 3217 : {'children': [3218]}
# 3216 : {'children': []}
# 3215 : {'children': [3216]}
# 3214 : {'transform': [-0.9950693915954536, 0.09626776143250618, 0.09183990482934318, 0.9040145841601889, -23.1375, 11.4125], 'children': [2553]}
# 3213 : {'children': [3214]}
# 3212 : {'children': [3213]}
# 3211 : {'transform': [-0.9687408582517625, 0.11829831240224851, 0.1037968116071485, 1.014575837520585, -2.3375, 27.05], 'children': [2621]}
# 3210 : {'children': [3211]}
# 3209 : {'children': [3210]}
# 3208 : {'transform': [-0.9263480618430412, 0.3208060715604137, 0.3192469185439553, 0.9464314622727849, 0.03750000000000009, 13.75], 'children': [2612]}
# 3207 : {'children': [3208]}
# 3206 : {'children': [3207]}
# 3205 : {'transform': [-0.9950626029514587, 0.09626773882752229, 0.10006107823316332, 0.994674680756434, -37.6625, 8.55], 'children': [2553]}
# 3204 : {'children': [3205]}
# 3203 : {'children': [3204]}
# 3202 : {'transform': [-0.9917745990688093, 0.12401049267860004, 0.12401049267859991, 0.9917745990688093, -23.5625, 41.462500000000006], 'children': [2546]}
# 3201 : {'children': [3202]}
# 3200 : {'children': [3201]}
# 3199 : {'transform': [-1.0000740541562667, 2.4503676176635973e-16, 0.0018225966033756404, 1.00003051757812, 3.9625000000000004, 52.05], 'children': [2522]}
# 3198 : {'children': [3199]}
# 3197 : {'children': [3198]}
# 3195 : {'children': []}
# 3194 : {'children': [3195]}
# 3193 : {'transform': [-0.916336059570312, -0.394378662109375, -0.394378662109375, 0.916336059570312, 27.25, -28.05], 'children': [2512]}
# 3192 : {'children': [3193]}
# 3191 : {'children': [3192]}
# 3190 : {'children': []}
# 3189 : {'children': [3190]}
# 3188 : {'children': []}
# 3187 : {'children': [3188]}
# 3186 : {'transform': [-1.0, -0.0224761962890625, 0.0, 1.0, 9.3, -16.65], 'children': [2501]}
# 3185 : {'children': [3186]}
# 3184 : {'children': [3185]}
# 3183 : {'children': []}
# 3182 : {'children': [3183]}
# 3181 : {'children': []}
# 3180 : {'children': [3181]}
# 3179 : {'children': []}
# 3178 : {'children': [3179]}
# 3164 : {'transform': [0.287216186523438, -0.0013885498046875, 0.021820068359375, 0.9632568359375, 48.95, -11.25], 'children': [2473]}
# 3163 : {'children': [3164]}
# 3162 : {'children': [3163]}
# 3165 : {'children': [3162]}
# 3177 : {'transform': [0.287216186523438, -0.0013885498046875, 0.021820068359375, 0.9632568359375, 48.95, -11.25], 'children': [2473]}
# 3176 : {'children': [3177]}
# 3175 : {'children': [3176]}
# 3174 : {'transform': [-0.328277587890625, -0.0022125244140625, -0.047454833984375, 0.727432250976562, 46.9, -5.55], 'children': [2455]}
# 3173 : {'children': [3174]}
# 3172 : {'children': [3173]}
# 3171 : {'transform': [-0.313751220703125, -0.130050659179688, -0.125015258789062, 0.576568603515625, 46.75, -4.2], 'children': [2448]}
# 3170 : {'children': [3171]}
# 3169 : {'children': [3170]}
# 3168 : {'transform': [-0.3939208984375, -0.249603271484375, -0.118606567382812, 0.656356811523438, 45.2, -10.55], 'children': [2441]}
# 3167 : {'children': [3168]}
# 3166 : {'children': [3167]}
# 3235 : {'mask': 3165, 'children': [3175, 3172, 3169, 3166]}
# 3148 : {'transform': [-0.999984741210938, 1.52587890625e-05, 0.0, 0.999984741210938, 4.75, -12.25], 'children': [2431]}
# 3147 : {'children': [3148]}
# 3146 : {'children': [3147]}
# 3149 : {'children': [3146]}
# 3161 : {'transform': [-0.999984741210938, 1.52587890625e-05, 0.0, 0.999984741210938, 4.75, -12.25], 'children': [2431]}
# 3160 : {'children': [3161]}
# 3159 : {'children': [3160]}
# 3158 : {'transform': [0.589889526367188, -0.020294189453125, 0.073760986328125, 0.758499145507812, 13.6, -6.8], 'children': [2455]}
# 3157 : {'children': [3158]}
# 3156 : {'children': [3157]}
# 3155 : {'transform': [-0.596832275390625, -0.138107299804688, -0.159149169921875, 0.697555541992188, 15.35, -5.8], 'children': [2448]}
# 3154 : {'children': [3155]}
# 3153 : {'children': [3154]}
# 3152 : {'transform': [-0.78961181640625, -0.0316009521484375, -0.0316009521484375, 0.78961181640625, 11.35, -10.35], 'children': [2441]}
# 3151 : {'children': [3152]}
# 3150 : {'children': [3151]}
# 3236 : {'mask': 3149, 'children': [3159, 3156, 3153, 3150]}
# 3145 : {'children': []}
# 3144 : {'children': [3145]}
# 3143 : {'transform': [0.287200927734375, -0.0013885498046875, 0.0333404541015625, 0.9632568359375, 49.7, -11.2], 'children': [2416]}
# 3142 : {'children': [3143]}
# 3141 : {'children': [3142]}
# 3140 : {'transform': [-0.999984741210938, 0.0103759765625, 0.0, 0.999984741210938, 4.75, -11.95], 'children': [2403]}
# 3139 : {'children': [3140]}
# 3138 : {'children': [3139]}
# 3137 : {'transform': [-1.0, -1.52587890625e-05, 0.082061767578125, 1.0, -14.55, -15.35], 'children': [2375]}
# 3136 : {'children': [3137]}
# 3135 : {'children': [3136]}
# 3237 : {'mask': 2363, 'children': [2369, 2364]}
# 3134 : {'transform': [0.944381713867188, -0.118316650390625, 0.123870849609375, 0.988800048828125, 80.35, -20.15], 'children': [2343]}
# 3133 : {'children': [3134]}
# 3132 : {'children': [3133]}
# 3131 : {'children': []}
# 3130 : {'children': [3131]}
# 3129 : {'children': []}
# 3128 : {'children': [3129]}
# 3127 : {'transform': [-1.0, 0.0, 0.12359619140625, 1.0, 22.3, 18.45], 'children': [2316]}
# 3126 : {'children': [3127]}
# 3125 : {'children': [3126]}
# 3124 : {'transform': [-1.0, 0.0, -0.003814697265625, 1.0, 22.2, 18.45], 'children': [2305]}
# 3123 : {'children': [3124]}
# 3122 : {'children': [3123]}
# 3121 : {'children': []}
# 3120 : {'children': [3121]}
# 3119 : {'children': []}
# 3118 : {'children': [3119]}
# 3117 : {'children': []}
# 3116 : {'children': [3117]}
# 3115 : {'children': []}
# 3114 : {'children': [3115]}
# 3113 : {'transform': [-0.9789123535156251, -0.07239216056504012, -0.04260253906249971, 1.041066625269698, 82.95000000000002, -44.325], 'children': [2290]}
# 3112 : {'children': [3113]}
# 3111 : {'children': [3112]}
# 3110 : {'transform': [-0.972763061523438, -0.07193446535455285, -0.042602539062499646, 1.0410656839187709, 17.35, -51.0125], 'children': [2283]}
# 3109 : {'children': [3110]}
# 3108 : {'children': [3109]}
# 3107 : {'transform': [-0.9729232787330259, -0.06084703160857035, -0.04260254251734019, 1.0413282607078707, 49.0625, -36.16250000000001], 'children': [2276]}
# 3106 : {'children': [3107]}

# %%
import numpy
import math

def polar_decomposition(matrix):
    u, s, vh = numpy.linalg.svd(matrix)
    pu = u @ vh # rotation matrix
    angle = math.atan2(pu[1,0], pu[0,0])
    
    pp = vh.T @ numpy.diag(s) @ vh # scaling matrix
#     scale = numpy.diag(pp)
#     skew = pp / scale
    return pp, angle # scale, angle, skew

def recompose_polar(scale, angle, skew):
    pp = numpy.multiply(skew, scale)
    pu = numpy.array([[math.cos(angle), -math.sin(angle)], [math.sin(angle), math.cos(angle)]])
    return pu @ pp

# scale, angle, skew = polar_decomposition(end)
# recon = recompose_polar(scale, angle, skew)
# print(recon)
# print(end)

# %%
start_props = polar_decomposition(start)
end_props = polar_decomposition(end)

steps = 20

diff_det = -(start_props[0] - end_props[0]) / (steps - 1)
diff_angle = 0 # -(start_props[1] - end_props[1]) / (steps-1)
diff_skew = 0 # -(start_props[2] - end_props[2]) / (steps-1)

print(diff_det, diff_angle, diff_skew)

current_det, current_angle, current_skew = start_props[:]

for i in range(steps-1):
    new_det = start_props[0] + i * diff_det
    new_angle = start_props[1] + i * diff_angle
    new_skew = start_props[2] + i * diff_skew
    print(recompose_polar(new_det, new_angle, new_skew))

# %%
from bs4 import BeautifulSoup
from glob import glob
from matplotlib import pyplot as plt

def read_matrices(path):
    for f in sorted(glob(path)):
        with open(f) as inp:
            soup = BeautifulSoup(inp.read(), 'html5lib')
            for g in soup.svg.findChildren('g', recursive=False):
                if g.has_attr('id'):
                    continue
                if g['transform']:
                    data = g['transform']
                    left = data.find('(') + 1
                    right = data.find(')')
                    elements = [float(x.strip()) for x in data[left:right].split(',')]
                    yield numpy.array(elements[:4]).reshape((2,2))
                    break

mats = list(read_matrices('/data/samples/tweens-both/*'))

def scales(m):
#     return numpy.linalg.svd(m)[1]
    scale, angle, skew = polar_decomposition(m)
    u, s, vt = numpy.linalg.svd(skew)
    return s
#     vals, vects = numpy.linalg.eig(m)
#     return vals
    

def decompose(m):
    mat = numpy.linalg.svd(m)
    angle = math.atan2(mat[0][1,0], mat[0][0,0])
    scale = mat[1]
    skew = mat[2]
#     return mat
#     return math.atan2(mat[1,0], mat[0,0]) % math.pi
#     pp, angle = polar_decomposition(m)
#     u, d, vt = numpy.linalg.svd(pp)
    
    return angle, scale, skew



plt.figure()
for i in range(len(mats) - 1):
    cur = decompose(mats[i])
    post = decompose(mats[i+1])
    
    d_angle = (post[0] - cur[0]) % math.pi - math.pi/2
    d_skew = (post[2] - cur[2]) % (math.pi / 2)
    d_scale = post[1] - cur[1]
    plt.plot(i, d_angle, 'k.')

plt.show()
plt.close()


# plt.figure()
# for i in range(len(mats) - 1):
#     cur = decompose(mats[i])
#     post = decompose(mats[i+1])
    
#     d_angle = (post[0] - cur[0]) % math.pi - math.pi
#     d_skew = (post[2] - cur[2]) % (math.pi / 2)
#     d_scale = post[1] - cur[1]
#     plt.plot(i, post[1][0] / cur[1][0], 'k.')

# plt.show()
# plt.close()


    
# d = [scales(x) for x in mats]
# for z in [x - y for x,y in zip(d[1:], d[:-1])]:
#     print(z)

# print('expected:', (scales(end) - scales(start)) / (len(d)))
# it overshoots by 2 on x, 3 on y until the last one, which corrects the overshoot?
# print(numpy.linalg.inv(mats[0]) @ mats[-1])
# print(numpy.linalg.inv(start) @ end)
